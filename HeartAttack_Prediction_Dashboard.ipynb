# %% [markdown]
# <a href="https://colab.research.google.com/github/chavan-sanika/Heart-Attack_Analysis/blob/main/HeartAttack_Prediction_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![HeartAttack_Prediction_dashboard.PNG](data:image/png;base64,...)
